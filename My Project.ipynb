# %% [markdown]
# ## __My Jupyter Notebook on IBM Watson Studio__

# %% [markdown]
# __Morenike D. Oyegbenro__

# %% [markdown]
# __I am currently a Data Scientist Trainee at a reputatble financial institution in Nigeria__

# %% [markdown]
# _I am interested in data science because i love to visualize and gain insights from data_

# %% [markdown]
# # __The following code tests for Simple Interest__

# %%
#To calculate the interest of stock sold
#Assigning values to the variables principal,rate and time
Principal=20000
Rate=5
Time=2
Simple_Interest=(20000*5*2)/100
print(Simple_Interest)
# Out:
# 2000.0
